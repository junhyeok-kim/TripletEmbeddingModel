# %% [markdown]
# # Extract Subject-Verb-Object (S, V, O) Triplets : VP Chunker version

# %%
import os
path_to_gs = "/usr/bin/gs"
os.environ['PATH'] += os.pathsep + path_to_gs
from nltk.chunk import conlltags2tree, tree2conlltags
# Classifier based tagger
from collections import Iterable
from nltk import ChunkParserI, ClassifierBasedTagger
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import conll2000  # training data for chunker
from nltk import pos_tag, word_tokenize
import random
import time
import re
import pandas as pd
import numpy as np

# =============================================================================
""" trained chunker """ 
# =============================================================================
def features(tokens, index, history):
    """
    `tokens`  = a POS-tagged sentence [(w1, t1), ...]
    `index`   = the index of the token we want to extract features for
    `history` = the previous predicted IOB tags
    """
    # init the stemmer
    stemmer = SnowballStemmer('english')
 
    # Pad the sequence with placeholders
    tokens = [('__START2__', '__START2__'), ('__START1__', '__START1__')] + list(tokens) + [('__END1__', '__END1__'), ('__END2__', '__END2__')]
    history = ['__START2__', '__START1__'] + list(history)
 
    # shift the index with 2, to accommodate the padding
    index += 2
 
    word, pos = tokens[index]
    prevword, prevpos = tokens[index - 1]
    prevprevword, prevprevpos = tokens[index - 2]
    nextword, nextpos = tokens[index + 1]
    nextnextword, nextnextpos = tokens[index + 2]
 
    return {
        'word': word,
        'lemma': stemmer.stem(word),
        'pos': pos,
 
        'next-word': nextword,
        'next-pos': nextpos,
 
        'next-next-word': nextnextword,
        'nextnextpos': nextnextpos,
 
        'prev-word': prevword,
        'prev-pos': prevpos,
 
        'prev-prev-word': prevprevword,
        'prev-prev-pos': prevprevpos,
    }
 
class ClassifierChunkParser(ChunkParserI):
    def __init__(self, chunked_sents, **kwargs):
        assert isinstance(chunked_sents, Iterable)
 
        # Transform the trees in IOB annotated sentences [(word, pos, chunk), ...]
        chunked_sents = [tree2conlltags(sent) for sent in chunked_sents]
 
        # Transform the triplets in pairs, make it compatible with the tagger interface [((word, pos), chunk), ...]
        def triplets2tagged_pairs(iob_sent):
            return [((word, pos), chunk) for word, pos, chunk in iob_sent]
        chunked_sents = [triplets2tagged_pairs(sent) for sent in chunked_sents]
 
        self.feature_detector = features
        self.tagger = ClassifierBasedTagger(
            train=chunked_sents,
            feature_detector=features,
            **kwargs)
 
    def parse(self, tagged_sent):
        chunks = self.tagger.tag(tagged_sent)
 
        # Transform the result from [((w1, t1), iob1), ...] 
        # to the preferred list of triplets format [(w1, t1, iob1), ...]
        iob_triplets = [(w, t, c) for ((w, t), c) in chunks]
 
        # Transform the list of triplets to nltk.Tree format
        return conlltags2tree(iob_triplets)

# %% [markdown]
# ## Train Chunker on 'conll2000' Datasets
#
# CoNLL2000 Datasets: `NP`: 55,081 (51%),  `VP`: 21467 (20%) ...

# %% [markdown]
# ###  only use 'VP' chunk_type

# %%
shuffled_conll_sents = list(conll2000.chunked_sents(chunk_types=['VP']))
random.shuffle(shuffled_conll_sents)
# train, test
train_sents = shuffled_conll_sents[:int(len(shuffled_conll_sents) * 0.9)]
test_sents = shuffled_conll_sents[int(len(shuffled_conll_sents) * 0.9 + 1):]  
# train chunker
VPchunker = ClassifierChunkParser(train_sents)

# %% [markdown]
# ### use 'NP' and 'VP' chunk_type

# %%
shuffled_conll_sents = list(conll2000.chunked_sents(chunk_types=['VP', 'NP']))
random.shuffle(shuffled_conll_sents)
train_sents = shuffled_conll_sents[:int(len(shuffled_conll_sents) * 0.9)]
test_sents = shuffled_conll_sents[int(len(shuffled_conll_sents) * 0.9 + 1):]  
print(len(train_sents), len(test_sents))
NPVPchunker = ClassifierChunkParser(train_sents)
# Out:
# 9853 1094

# %%
import pandas as pd
dat_path = '/home/junhyuki/DLproject/DAT'
usecols=['connected_url', 'keywords', 'timestamp', 'clean_title', 'location']
df = pd.read_csv(dat_path + '/1-DailyNews/cleaned_news_2012.csv', usecols=usecols, nrows=100)
df
# Out:
#                                         connected_url  \
# 0   http://www.reuters.com/article/2012/01/02/us-f...
# 1   http://www.reuters.com/article/2012/01/02/us-n...
# 2   http://www.reuters.com/article/2012/01/02/us-n...
# 3   http://www.reuters.com/article/2012/01/02/us-n...
# 4   http://www.reuters.com/article/2012/01/02/us-c...
# 5   http://www.reuters.com/article/2012/01/02/us-c...
# 6   http://www.reuters.com/article/2012/01/02/idUS...
# 7   http://www.reuters.com/article/2012/01/02/us-n...
# 8   http://www.reuters.com/article/2012/01/02/us-c...
# 9   http://www.reuters.com/article/2012/01/02/us-k...
# 10  http://www.reuters.com/article/2012/01/02/us-i...
# 11  http://www.reuters.com/article/2012/01/02/us-f...
# 12  http://www.reuters.com/article/2012/01/02/free...
# 13  http://www.reuters.com/article/2012/01/02/pse-...
# 14  http://www.reuters.com/article/2012/01/02/mark...
# 15  http://www.reuters.com/article/2012/01/02/us-h...
# 16  http://www.reuters.com/article/2012/01/02/us-n...
# 17  http://www.reuters.com/article/2012/01/02/hyun...
# 18  http://www.reuters.com/article/2012/01/02/phil...
# 19  http://www.reuters.com/article/2012/01/02/us-s...
# 20  http://www.reuters.com/article/2012/01/02/us-f...
# 21  http://www.reuters.com/article/2012/01/02/us-s...
# 22  http://www.reuters.com/article/2012/01/02/us-w...
# 23  http://www.reuters.com/article/2012/01/02/us-n...
# 24  http://www.reuters.com/article/2012/01/01/us-u...
# 25  http://www.reuters.com/article/2012/01/01/us-u...
# 26  http://www.reuters.com/article/2012/01/01/us-u...
# 27  http://www.reuters.com/article/2012/01/01/us-u...
# 28  http://www.reuters.com/article/2012/01/01/us-s...
# 29  http://www.reuters.com/article/2012/01/01/us-h...
# ..                                                ...
# 70  http://www.reuters.com/article/2012/01/01/maer...
# 71  http://www.reuters.com/article/2012/01/01/euro...
# 72  http://www.reuters.com/article/2012/01/01/us-p...
# 73  http://www.reuters.com/article/2012/01/01/us-h...
# 74  http://www.reuters.com/article/2012/01/01/us-k...
# 75  http://www.reuters.com/article/2012/01/01/us-i...
# 76  http://www.reuters.com/article/2012/01/01/isra...
# 77  http://www.reuters.com/article/2012/01/01/us-n...
# 78  http://www.reuters.com/article/2012/01/01/leum...
# 79  http://www.reuters.com/article/2012/01/01/idUS...
# 80  http://www.reuters.com/article/2012/01/01/us-t...
# 81  http://www.reuters.com/article/2012/01/01/us-l...
# 82  http://www.reuters.com/article/2012/01/01/us-i...
# 83  http://www.reuters.com/article/2012/01/01/us-s...
# 84  http://www.reuters.com/article/2012/01/01/shel...
# 85  http://www.reuters.com/article/2012/01/01/us-k...
# 86  http://www.reuters.com/article/2012/01/01/us-f...
# 87  http://www.reuters.com/article/2012/01/01/us-i...
# 88  http://www.reuters.com/article/2012/01/01/us-e...
# 89  http://www.reuters.com/article/2012/01/01/mali...
# 90  http://www.reuters.com/article/2012/01/01/us-c...
# 91  http://www.reuters.com/article/2012/01/01/euro...
# 92  http://www.reuters.com/article/2012/01/01/us-i...
# 93  http://www.reuters.com/article/2012/01/01/us-r...
# 94  http://www.reuters.com/article/2012/01/01/us-j...
# 95  http://www.reuters.com/article/2012/01/01/us-n...
# 96  http://www.reuters.com/article/2012/01/01/us-n...
# 97  http://www.reuters.com/article/2012/01/01/us-i...
# 98  http://www.reuters.com/article/2012/01/01/nort...
# 99  http://www.reuters.com/article/2012/01/01/us-i...
#
#                                              keywords  timestamp  \
# 0   Juan Salceto;Stephen Glatstein;US;FOOTBALL;ACC...   20120101
# 1   Ian Cole;Justin Abdelkader;US;NHL;BLUES;COLE;N...   20120101
# 2   Barry Trotz;Brendan Morrison;Jarome Iginla;Kev...   20120101
# 3   Mark Leffingwell;Tim Tebow;US;NFL;BRONCOS;Spor...   20120101
# 4   Cuba;Mexico;Benedict XVI;Fidel Castro;Raul Cas...   20120101
# 5   US;CHINA;LAWYER;Crime / Law / Justice;Fundamen...   20120101
# 6   India;N.K. Nanda;Rana Som;Commodities Markets;...   20120101
# 7   John Sommers II;Ray Rice;US;NFL;RAVENS;Sport;N...   20120101
# 8   Colombia;Panama;United States;Venezuela;Juan d...   20120101
# 9   China;Korea;South Korea;Taiwan;United States;C...   20120101
# 10  India;Jagannadham Thunuguntla;BSE 30;US;INDIA;...   20120101
# 11  Indonesia;Virgo Solossa;US;FREEPORT;INDONESIA;...   20120101
# 12  Indonesia;Virgo Solossa;FREEPORT;INDONESIA;Com...   20120101
# 13  PSE/;Investment Banking and Investment Service...   20120101
# 14  MARKETS;KOREA/(URGENT);Investment Banking and ...   20120101
# 15  US;HYUNDAIHEAVY;ORDERS;Results Forecasts / War...   20120101
# 16  Alex Smith;Sarah Conard;US;NFL;49ERS;Sport;NFL...   20120101
# 17  HYUNDAIHEAVY;ORDERS;Results Forecasts / Warnin...   20120101
# 18  PHILIPPINES;MARKETS/;Agricultural Markets;Ener...   20120101
# 19  US;SPACE;MOON;Industrials (TRBC);Science;Indus...   20120101
# 20  Australia;Fiji;Frank Bainimarama;Ratu Josefa I...   20120101
# 21                  Larry Nesbit;US;SHOOTING;CORONADO   20120101
# 22  Canada;Japan;United States;A. Amanda Ware;John...   20120101
# 23  Adam Hunger;Tom Brady;US;NFL;PATRIOTS;Sport;NF...   20120101
# 24  United States;Alicia Vanderveer;Barack Obama;E...   20120101
# 25  United States;Al Gore;Ann Romney;Barack Obama;...   20120101
# 26  John Gress;Rick Santorum;US;USA;CAMPAIGN;SANTO...   20120101
# 27  Alicia Vanderveer;Barack Obama;Michele Bachman...   20120101
# 28  US;SYRIA;Human Rights / Civil Rights;Lebanon;S...   20120101
# 29  Chung Mong;koo;Lee Jae;Won;US;HYUNDAI;KIA;Auto...   20120101
# ..                                                ...        ...
# 70  MAERSK/CEO;Commodities Markets;Energy Markets;...   20120101
# 71  France;Germany;Greece;Ireland;Italy;Portugal;U...   20120101
# 72  Cuba;Lebanon;Mexico;Addressing Benedict;US;POP...   20120101
# 73  United States;Alexis Bagley;Benny Hill;Lee Har...   20120101
# 74  Kenya;Somalia;Al Shabaab;Leo Nyongesa;US;KENYA...   20120101
# 75  Israel;US;ISRAELCHEMICALS;SALT;Chemicals (Lega...   20120101
# 76  ISRAELCHEMICALS;SALT/;Basic Materials (TRBC);C...   20120101
# 77  Cameroon;Chad;Niger;Nigeria;Boko Haram;Goodluc...   20120101
# 78  LEUMI;CEO/RESIGNATION;Banking Services (TRBC);...   20120101
# 79  Automobiles / Auto Parts (Legacy);Automobiles ...   20120101
# 80  Australia;Spain;Anabel Medina Garrigues;Fernan...   20120101
# 81  US;LIBYA;EXPLOSIVES;PLOT;Middle East;Military ...   20120101
# 82  US;ITALY;FIREWORKS;Crime / Law / Justice;Weste...   20120101
# 83  Belgium;France;Switzerland;Peter Voser;Thomas ...   20120101
# 84  SHELL/PETROPLUS;Commodities Markets;Germany;En...   20120101
# 85  N.Korea;North Korea;South Korea;United States;...   20120101
# 86  Barack Obama;Dwight Eisenhower;George W. Bush;...   20120101
# 87  Iraq;United States;Nuri al;Maliki;US;IRAQ;VIOL...   20120101
# 88  Brazil;China;France;Germany;Greece;India;Italy...   20120101
# 89  MALI;GOLD/REVENUE;Commodities Markets;Basic Ma...   20120101
# 90  Congo;Democratic Republic of Congo;Gaston Luze...   20120101
# 91  EUROPE;STANDARDCHARTERED/SPLIT;Banking Service...   20120101
# 92  China;France;Germany;Islamic Republic of Iran;...   20120101
# 93  United States;Al Gore;Ann Romney;Barack Obama;...   20120101
# 94  Japan;Singapore;United States;Kiyoshi Takenaka...   20120101
# 95  China;France;Germany;Islamic Republic of Iran;...   20120101
# 96  United Kingdom;David Clementi;Jayne;Anne Gadhi...   20120101
# 97  Iraq;United States;Amjad Abdul;Salam;Daham al;...   20120101
# 98  NORTHERNROCK/;Banking Services (TRBC);Banks (T...   20120101
# 99  Israel;Avner Shalev;Benjamin Netanyahu;Ehud Ba...   20120101
#
#                                           clean_title   location
# 0   Oakland Raiders fan falls from bleachers after...        NaN
# 1               Blues' Cole suspended for three games        NaN
# 2   Kostitsyn's hat-trick helps Predators douse Fl...        NaN
# 3       Broncos clinch AFC West, snap playoff drought        NaN
# 4         Pope Benedict XVI to visit Cuba March 26-28        NaN
# 5       China dissident-lawyer Gao jailed in far west        NaN
# 6   Govt appoints 3-month interim head for India's...        NaN
# 7     Ravens earn AFC North title and first-round bye        NaN
# 8   Colombian police kill leader of powerful drug ...        NaN
# 9      S. Korea manufacturing shrinks most in 3 years        NaN
# 10     India lets foreign individuals invest in stock        NaN
# 11  Freeport Indonesia union says delays return to...        NaN
# 12  Freeport Indonesia union says delays return to...        NaN
# 13    Philippine stock exchange extends trading hours        NaN
# 14             Seoul shares inch up, tech shares lead        NaN
# 15  Hyundai Heavy targets 20 percent order growth ...        NaN
# 16          Proud 49ers secure bye with win over Rams        NaN
# 17  Hyundai Heavy targets 20 pct order growth in 2...        NaN
# 18                    Market factors to watch - Jan 2        NaN
# 19  NASA probes reach moon for gravity-mapping mis...  CANAVERAL
# 20                        Fiji to lift emergency laws        NaN
# 21  Four dead in apparent murder-suicide near San ...        NaN
# 22  Ohio suspends well operations after series of ...        NaN
# 23  Brady joins "5,000 club" as Patriots get top seed        NaN
# 24  With 48 hours left, Romney eyes Iowa breakthrough        NaN
# 25  Romney runs strong, but can he connect with vo...        NaN
# 26  Surging Rick Santorum urges Iowa to send "shoc...        NaN
# 27        Bachmann seeks miracle in presidential race        NaN
# 28        Syria bloodshed defies Arab monitor mission        NaN
# 29      Hyundai, Kia eye 6 percent sales rise in 2012        NaN
# ..                                                ...        ...
# 70       Maersk says CEO on leave after heart surgery        NaN
# 71  Crisis talk, austerity calls mark euro anniver...        NaN
# 72  Educate young for peace, pope says at New Year...        NaN
# 73  Supersized saddles find home on the range as A...        NaN
# 74      Gunmen attack bars in northeast Kenya, 5 dead        NaN
# 75  Israel cabinet approves ICL's Dead Sea salt ex...        NaN
# 76  Israel cabinet OKs ICL's Dead Sea salt extraction        NaN
# 77          Troops, tanks patrol in northeast Nigeria        NaN
# 78  Israel's Bank Leumi CEO Maor steps down after ...        NaN
# 79  Porsche wants car sales to grow faster than ma...        NaN
# 80    Verdasco spoils Hewitt's comeback in Hopman Cup        NaN
# 81  Libya militia says holds Gaddafi supporters ov...        NaN
# 82  Two die, 561 hurt in Italian New Year celebrat...        NaN
# 83           Shell CEO keeping close eye on Petroplus        NaN
# 84     Shell CEO keeping close eye on Petroplus-paper     ZURICH
# 85  North Korea calls for "human shields" to prote...        NaN
# 86  Three early voting states in presidential elec...        NaN
# 87  Iraqi civilian deaths in December lowest level...        NaN
# 88       West in political crisis has echoes of 1930s        NaN
# 89    Mali gold revenues rise in 2011 alongside price        NaN
# 90      Nine die, 50 hurt in botched Congo jail break        NaN
# 91  Standard Chartered sees higher risk of euro split        NaN
# 92  Iran successfully tests domestically made nucl...        NaN
# 93  Romney runs strong, but can he connect with vo...        NaN
# 94  Strong earthquake jolts Japan, no tsunami warning        NaN
# 95   EU sees January decision on wider Iran sanctions        NaN
# 96   UK sells Northern Rock to Virgin despite protest        NaN
# 97  Feeling marginalized, some Iraq Sunnis eye aut...        NaN
# 98   UK sells Northern Rock to Virgin despite protest        NaN
# 99  Holocaust garb causes outrage in Israel faith row        NaN
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Test1: VP chunker -> Ignore NNS, NN in 'VP' case
#
# This test doesn't produce satisfactory results, since TRAINED POS-tagging model cannot caputre real VERB (They reconize them as NNS(pluran nouns) or NN(singular noun))

# %%
import numpy as np

def ExtractSVO_usingVPchunker(text):
    """ For simplicity, we assume that if there are more than 2 'VP':
        -> We select First 'VP' 
    
    Error Type:
        text='Jinke Property wins land auctions in Chongqing for 117.9 mln yuan'
        > nltk.pos_tag recognize 'wins' as plural noun (NNS)
    """
    vp = []
    tree = VPchunker.parse(pos_tag(word_tokenize(text)))
    print(text)
    for child in tree:
        if str(type(child)) == "<class 'nltk.tree.Tree'>":
            if re.findall('/N', str(child)) != []:
                print('This is Not the case of Verb Phrase : ' + str(child))
            else:
                vp.append(child)
    if vp == []:
        s, v, o = np.nan, np.nan, np.nan
    else:
        if len(vp) > 1:
            vp = vp[0]  # use first 'VP' if all doesn't have prefix 'N'
            # Tree('VP', [...]) shape
            if len(vp) != 1:
                vp_ = ' '.join([x[0] for x in vp])
            else:
                vp_ = vp[0][0]
        else:
            # [Tree('VP', [...])] shape
            if len(vp) != 1:
                vp_ = ' '.join([x[0] for x in vp[0]])
            else:
                vp_ = vp[0][0][0]
        print(' ------> VP: ' + vp_)
        
        # e.g. +76 can be captured as 'verb' -> then because of special characters in `regex`, we need to use r'
        # But we can think that this type of verb is somewhat error, so pass!
        try:
            m = re.search(vp_, text)
            start = m.start()
            end = m.end()
            s = text[:start].strip()
            v = vp_.strip()
            o = text[end:].strip()            
        except:
            s, v, o = np.nan, np.nan, np.nan
        
    return s, v, o

# %%
df['clean_title'].apply(ExtractSVO_usingVPchunker)
# Out:
# Oakland Raiders fan falls from bleachers after game
#  ------> VP: falls
# Blues' Cole suspended for three games
#  ------> VP: suspended
# Kostitsyn's hat-trick helps Predators douse Flames
# This is Not the case of Verb Phrase : (VP helps/NN)
# This is Not the case of Verb Phrase : (VP Predators/NNS)
#  ------> VP: douse
# Broncos clinch AFC West, snap playoff drought
# This is Not the case of Verb Phrase : (VP clinch/NN)
#  ------> VP: snap
# Pope Benedict XVI to visit Cuba March 26-28
# This is Not the case of Verb Phrase : (VP Benedict/NNP)
# This is Not the case of Verb Phrase : (VP XVI/NNP)
#  ------> VP: to
# China dissident-lawyer Gao jailed in far west
# This is Not the case of Verb Phrase : (VP dissident-lawyer/NN)
#  ------> VP: jailed
# Govt appoints 3-month interim head for India's NMDC
# This is Not the case of Verb Phrase : (VP appoints/NNS)
#  ------> VP: 3-month
# Ravens earn AFC North title and first-round bye
#  ------> VP: earn
# Colombian police kill leader of powerful drug gang
#  ------> VP: kill
# S. Korea manufacturing shrinks most in 3 years
# India lets foreign individuals invest in stock
#  ------> VP: lets
# Freeport Indonesia union says delays return to work
#  ------> VP: says
# Freeport Indonesia union says delays return to work
#  ------> VP: says
# Philippine stock exchange extends trading hours
#  ------> VP: extends
# Seoul shares inch up, tech shares lead
#  ------> VP: inch
# Hyundai Heavy targets 20 percent order growth to $31 billion
# This is Not the case of Verb Phrase : (VP targets/NNS)
#  ------> VP: to
# Proud 49ers secure bye with win over Rams
# This is Not the case of Verb Phrase : (VP win/NN)
# Hyundai Heavy targets 20 pct order growth in 2012 to $31 bln
# This is Not the case of Verb Phrase : (VP targets/NNS)
#  ------> VP: to
# Market factors to watch - Jan 2
#  ------> VP: to
# NASA probes reach moon for gravity-mapping mission
# This is Not the case of Verb Phrase : (VP probes/NNS)
# This is Not the case of Verb Phrase : (VP reach/VBP moon/NN)
# Fiji to lift emergency laws
#  ------> VP: to
# Four dead in apparent murder-suicide near San Diego
# Ohio suspends well operations after series of small quakes
#  ------> VP: suspends
# Brady joins "5,000 club" as Patriots get top seed
#  ------> VP: joins
# With 48 hours left, Romney eyes Iowa breakthrough
#  ------> VP: left
# Romney runs strong, but can he connect with voters?
#  ------> VP: runs
# Surging Rick Santorum urges Iowa to send "shock wave"
# This is Not the case of Verb Phrase : (VP urges/VBZ Iowa/NNP)
#  ------> VP: to
# Bachmann seeks miracle in presidential race
# This is Not the case of Verb Phrase : (VP seeks/VBZ miracle/NN)
# Syria bloodshed defies Arab monitor mission
# This is Not the case of Verb Phrase : (VP bloodshed/VBD defies/NNS)
# Hyundai, Kia eye 6 percent sales rise in 2012
# This is Not the case of Verb Phrase : (VP rise/NN)
# Hyundai, Kia eye 6 pct sales rise in 2012
# Hyundai, Kia eye 6 pct rise in 2012 sales -chairman
# Shortage of ADHD drug Adderall seen persisting
# This is Not the case of Verb Phrase : (VP Adderall/NNP)
#  ------> VP: seen
# Israel, Palestinians to meet Tuesday; prospects hazy
# This is Not the case of Verb Phrase : (VP Palestinians/NNPS)
#  ------> VP: to
# Exxon wins less than expected from Venezuela dispute
#  ------> VP: wins
# Mount Rainier National Park ranger killed, gunman loose
#  ------> VP: killed
# Patriots, 49ers clinch advantages for playoffs
# Egypt's army hastens end of parliamentary election
# This is Not the case of Verb Phrase : (VP hastens/VBZ end/NN)
# Egypt denies trying to stifle human rights movement
#  ------> VP: denies
# Libya's al-Sedr oil port resumes operations
# U.S. fighter sales soar in time for campaign
#  ------> VP: soar
# Boat capsizes off Lamu in Kenya, at least 7 dead
#  ------> VP: capsizes
# New York police arrest dozens of anti-Wall Street protesters
# Four dead in shooting near San Diego
# Wisconsin man, 82, calls 60th polar bear plunge his last
#  ------> VP: calls
# 49ers secure playoff bye with win over Rams
# This is Not the case of Verb Phrase : (VP secure/VBP playoff/NN)
# This is Not the case of Verb Phrase : (VP bye/NN)
# This is Not the case of Verb Phrase : (VP win/NN)
# Brady joins "5,000 club" as Patriots secure home field
#  ------> VP: joins
# Throngs of Times Square revelers ring in 2012
# This is Not the case of Verb Phrase : (VP revelers/NNS)
#  ------> VP: ring
# UK's Prince Philip walks to church after operation
# This is Not the case of Verb Phrase : (VP walks/NNS)
#  ------> VP: to
# Tunisian president says liberties to be protected
#  ------> VP: says
# Arson damages historic Illinois clock factory, teens held
#  ------> VP: historic
# U.S. consumer in the slow lane
# Nigeria ends fuel subsidies, angering unions
#  ------> VP: ends
# Iran reports nuclear progress as sanctions loom
# Funeral of Bahrain youth turns into street protest
#  ------> VP: turns
# In new year, nation sees winter weather at last
# This is Not the case of Verb Phrase : (VP sees/NNS)
# This is Not the case of Verb Phrase : (VP winter/VBP weather/NN)
# Accusations fly as oil slick hits Nigeria coast
#  ------> VP: fly
# Accusations fly as oil slick hits Nigeria coast
#  ------> VP: fly
# Zooey Deschanel finds music a (Pooh) bear necessity
#  ------> VP: finds
# Celebrities may temper Twitter comments after 2011 blunders
# This is Not the case of Verb Phrase : (VP may/MD temper/VB Twitter/NNP)
# Time Warner, MSG at odds over sports network rates
# Workers at Tripoli's decaying port go on strike
#  ------> VP: decaying
# Stolen monkey returned to San Francisco Zoo
# This is Not the case of Verb Phrase : (VP monkey/NN)
#  ------> VP: returned
# Workers at Tripoli's decaying port go on strike
#  ------> VP: decaying
# Arbitration cases against Venezuela nationalizations
# Iran reports nuclear progress as sanctions loom
# You thought 2011 was tough?
#  ------> VP: thought
# U.S. is top 2012 property investment pick
#  ------> VP: is
# Iceland's president says he will step down in May
#  ------> VP: says
# Crisis talk, austerity calls mark euro anniversary
#  ------> VP: calls
# Maersk says CEO on leave after heart surgery
#  ------> VP: says
# Crisis talk, austerity calls mark euro anniversary
#  ------> VP: calls
# Educate young for peace, pope says at New Year Mass
#  ------> VP: says
# Supersized saddles find home on the range as Americans fatten
#  ------> VP: find
# Gunmen attack bars in northeast Kenya, 5 dead
# This is Not the case of Verb Phrase : (VP bars/NNS)
# Israel cabinet approves ICL's Dead Sea salt extraction
#  ------> VP: approves
# Israel cabinet OKs ICL's Dead Sea salt extraction
# This is Not the case of Verb Phrase : (VP cabinet/NN)
# Troops, tanks patrol in northeast Nigeria
#  ------> VP: patrol
# Israel's Bank Leumi CEO Maor steps down after 16 years
# This is Not the case of Verb Phrase : (VP CEO/NNP)
# This is Not the case of Verb Phrase : (VP steps/NNS)
# Porsche wants car sales to grow faster than market
#  ------> VP: wants
# Verdasco spoils Hewitt's comeback in Hopman Cup
#  ------> VP: spoils
# Libya militia says holds Gaddafi supporters over plot
#  ------> VP: says
# Two die, 561 hurt in Italian New Year celebrations
# This is Not the case of Verb Phrase : (VP hurt/NN)
# Shell CEO keeping close eye on Petroplus
# This is Not the case of Verb Phrase : (VP CEO/NNP)
#  ------> VP: keeping
# Shell CEO keeping close eye on Petroplus-paper
# This is Not the case of Verb Phrase : (VP CEO/NNP)
#  ------> VP: keeping
# North Korea calls for "human shields" to protect new leader
#  ------> VP: calls
# Three early voting states in presidential election
# Iraqi civilian deaths in December lowest level in 2011
# West in political crisis has echoes of 1930s
# This is Not the case of Verb Phrase : (VP has/VBZ echoes/NNS)
# Mali gold revenues rise in 2011 alongside price
#  ------> VP: rise
# Nine die, 50 hurt in botched Congo jail break
# This is Not the case of Verb Phrase : (VP die/NN)
# This is Not the case of Verb Phrase : (VP hurt/NN)
# Standard Chartered sees higher risk of euro split
#  ------> VP: sees
# Iran successfully tests domestically made nuclear fuel rods
#  ------> VP: tests
# Romney runs strong, but can he connect with voters?
#  ------> VP: runs
# Strong earthquake jolts Japan, no tsunami warning
# EU sees January decision on wider Iran sanctions
#  ------> VP: sees
# UK sells Northern Rock to Virgin despite protest
#  ------> VP: sells
# Feeling marginalized, some Iraq Sunnis eye autonomy
# UK sells Northern Rock to Virgin despite protest
#  ------> VP: sells
# Holocaust garb causes outrage in Israel faith row
# This is Not the case of Verb Phrase : (VP garb/NN)
# This is Not the case of Verb Phrase : (VP causes/VBZ outrage/NN)
# 0     (Oakland Raiders fan, falls, from bleachers af...
# 1             (Blues' Cole, suspended, for three games)
# 2     (Kostitsyn's hat-trick helps Predators, douse,...
# 3     (Broncos clinch AFC West,, snap, playoff drought)
# 4       (Pope Benedict XVI, to, visit Cuba March 26-28)
# 5     (China dissident-lawyer Gao, jailed, in far west)
# 6     (Govt appoints, 3-month, interim head for Indi...
# 7     (Ravens, earn, AFC North title and first-round...
# 8     (Colombian police, kill, leader of powerful dr...
# 9                                       (nan, nan, nan)
# 10    (India, lets, foreign individuals invest in st...
# 11    (Freeport Indonesia union, says, delays return...
# 12    (Freeport Indonesia union, says, delays return...
# 13    (Philippine stock exchange, extends, trading h...
# 14           (Seoul shares, inch, up, tech shares lead)
# 15    (Hyundai Heavy targets 20 percent order growth...
# 16                                      (nan, nan, nan)
# 17    (Hyundai Heavy targets 20 pct order growth in ...
# 18                (Market fac, to, rs to watch - Jan 2)
# 19                                      (nan, nan, nan)
# 20                      (Fiji, to, lift emergency laws)
# 21                                      (nan, nan, nan)
# 22    (Ohio, suspends, well operations after series ...
# 23    (Brady, joins, "5,000 club" as Patriots get to...
# 24    (With 48 hours, left, , Romney eyes Iowa break...
# 25    (Romney, runs, strong, but can he connect with...
# 26    (Surging Rick San, to, rum urges Iowa to send ...
# 27                                      (nan, nan, nan)
# 28                                      (nan, nan, nan)
# 29                                      (nan, nan, nan)
#                             ...
# 70     (Maersk, says, CEO on leave after heart surgery)
# 71    (Crisis talk, austerity, calls, mark euro anni...
# 72    (Educate young for peace, pope, says, at New Y...
# 73    (Supersized saddles, find, home on the range a...
# 74                                      (nan, nan, nan)
# 75    (Israel cabinet, approves, ICL's Dead Sea salt...
# 76                                      (nan, nan, nan)
# 77        (Troops, tanks, patrol, in northeast Nigeria)
# 78                                      (nan, nan, nan)
# 79    (Porsche, wants, car sales to grow faster than...
# 80    (Verdasco, spoils, Hewitt's comeback in Hopman...
# 81    (Libya militia, says, holds Gaddafi supporters...
# 82                                      (nan, nan, nan)
# 83         (Shell CEO, keeping, close eye on Petroplus)
# 84    (Shell CEO, keeping, close eye on Petroplus-pa...
# 85    (North Korea, calls, for "human shields" to pr...
# 86                                      (nan, nan, nan)
# 87                                      (nan, nan, nan)
# 88                                      (nan, nan, nan)
# 89    (Mali gold revenues, rise, in 2011 alongside p...
# 90                                      (nan, nan, nan)
# 91    (Standard Chartered, sees, higher risk of euro...
# 92    (Iran successfully, tests, domestically made n...
# 93    (Romney, runs, strong, but can he connect with...
# 94                                      (nan, nan, nan)
# 95    (EU, sees, January decision on wider Iran sanc...
# 96    (UK, sells, Northern Rock to Virgin despite pr...
# 97                                      (nan, nan, nan)
# 98    (UK, sells, Northern Rock to Virgin despite pr...
# 99                                      (nan, nan, nan)
# Name: clean_title, Length: 100, dtype: object

# %% [markdown]
# ## Test2: VP chunker -> Accept NNS, NN in 'VP' case

# %%
def ExtractSVO_usingVPchunker(text):
    """ For simplicity, we assume that if there are more than 2 'VP':
        -> We select First 'VP' 
    
    Error Type:
        text='Jinke Property wins land auctions in Chongqing for 117.9 mln yuan'
        > nltk.pos_tag recognize 'wins' as plural noun (NNS)
    """
    vp = []
    tree = VPchunker.parse(pos_tag(word_tokenize(text)))
    for child in tree:
        if str(type(child)) == "<class 'nltk.tree.Tree'>":
            if re.findall(r'\bVP\b', str(child)) != []:
                vp.append(child)
    if vp == []:
        s, v, o = np.nan, np.nan, np.nan
    else:
        if len(vp) > 1:
            vp = vp[0]  # use first 'VP' if all doesn't have prefix 'N'
            # Tree('VP', [...]) shape
            if len(vp) != 1:
                vp_ = ' '.join([x[0] for x in vp])
            else:
                vp_ = vp[0][0]
        else:
            # [Tree('VP', [...])] shape
            if len(vp[0]) != 1:
                vp_ = ' '.join([x[0] for x in vp[0]])
            else:
                vp_ = vp[0][0][0]
        # e.g. +76 can be captured as 'verb' -> then because of special characters in `regex`, we need to use r'
        # But we can think that this type of verb is somewhat error, so pass!
        try:
            m = re.search(vp_, text)
            start = m.start()
            end = m.end()
            s = text[:start].strip()
            v = vp_.strip()
            o = text[end:].strip()
        except:
            s, v, o = np.nan, np.nan, np.nan
                
    return s, v, o

# %%
df['clean_title'].apply(ExtractSVO_usingVPchunker)
# Out:
# 0     (Oakland Raiders fan, falls, from bleachers af...
# 1             (Blues' Cole, suspended, for three games)
# 2     (Kostitsyn's hat-trick, helps, Predators douse...
# 3     (Broncos, clinch, AFC West, snap playoff drought)
# 4       (Pope, Benedict, XVI to visit Cuba March 26-28)
# 5     (China, dissident-lawyer, Gao jailed in far west)
# 6     (Govt, appoints, 3-month interim head for Indi...
# 7     (Ravens, earn, AFC North title and first-round...
# 8     (Colombian police, kill, leader of powerful dr...
# 9                                       (nan, nan, nan)
# 10    (India, lets, foreign individuals invest in st...
# 11    (Freeport Indonesia union, says, delays return...
# 12    (Freeport Indonesia union, says, delays return...
# 13    (Philippine stock exchange, extends, trading h...
# 14           (Seoul shares, inch, up, tech shares lead)
# 15    (Hyundai Heavy, targets, 20 percent order grow...
# 16        (Proud 49ers secure bye with, win, over Rams)
# 17    (Hyundai Heavy, targets, 20 pct order growth i...
# 18                  (Market factors, to watch, - Jan 2)
# 19    (NASA, probes, reach moon for gravity-mapping ...
# 20                      (Fiji, to lift, emergency laws)
# 21                                      (nan, nan, nan)
# 22    (Ohio, suspends, well operations after series ...
# 23    (Brady, joins, "5,000 club" as Patriots get to...
# 24    (With 48 hours, left, , Romney eyes Iowa break...
# 25    (Romney, runs, strong, but can he connect with...
# 26    (Surging Rick Santorum, urges Iowa, to send "s...
# 27      (Bachmann, seeks miracle, in presidential race)
# 28      (Syria, bloodshed defies, Arab monitor mission)
# 29    (Hyundai, Kia eye 6 percent sales, rise, in 2012)
#                             ...
# 70     (Maersk, says, CEO on leave after heart surgery)
# 71    (Crisis talk, austerity, calls, mark euro anni...
# 72    (Educate young for peace, pope, says, at New Y...
# 73    (Supersized saddles, find, home on the range a...
# 74    (Gunmen attack, bars, in northeast Kenya, 5 dead)
# 75    (Israel cabinet, approves, ICL's Dead Sea salt...
# 76    (Israel, cabinet, OKs ICL's Dead Sea salt extr...
# 77        (Troops, tanks, patrol, in northeast Nigeria)
# 78    (Israel's Bank Leumi, CEO, Maor steps down aft...
# 79    (Porsche, wants, car sales to grow faster than...
# 80    (Verdasco, spoils, Hewitt's comeback in Hopman...
# 81    (Libya militia, says, holds Gaddafi supporters...
# 82    (Two die, 561, hurt, in Italian New Year celeb...
# 83         (Shell, CEO, keeping close eye on Petroplus)
# 84    (Shell, CEO, keeping close eye on Petroplus-pa...
# 85    (North Korea, calls, for "human shields" to pr...
# 86                                      (nan, nan, nan)
# 87                                      (nan, nan, nan)
# 88     (West in political crisis, has echoes, of 1930s)
# 89    (Mali gold revenues, rise, in 2011 alongside p...
# 90    (Nine, die, , 50 hurt in botched Congo jail br...
# 91    (Standard Chartered, sees, higher risk of euro...
# 92    (Iran successfully, tests domestically made, n...
# 93    (Romney, runs, strong, but can he connect with...
# 94                                      (nan, nan, nan)
# 95    (EU, sees, January decision on wider Iran sanc...
# 96    (UK, sells, Northern Rock to Virgin despite pr...
# 97                                      (nan, nan, nan)
# 98    (UK, sells, Northern Rock to Virgin despite pr...
# 99    (Holocaust, garb, causes outrage in Israel fai...
# Name: clean_title, Length: 100, dtype: object

# %% [markdown]
# ## Test3: NPVP chunker -> Accept NNS, NN in 'VP' case

# %%
def ExtractSVO_usingNPVPchunker(text):
    """ For simplicity, we assume that if there are more than 2 'VP':
        -> We select First 'VP' 
    
    Error Type:
        text='Jinke Property wins land auctions in Chongqing for 117.9 mln yuan'
        > nltk.pos_tag recognize 'wins' as plural noun (NNS)
    """
    vp = []
    tree = NPVPchunker.parse(pos_tag(word_tokenize(text)))
    for child in tree:
        if str(type(child)) == "<class 'nltk.tree.Tree'>":
            if re.findall(r'\bVP\b', str(child)) != []:
                vp.append(child)
    if vp == []:
        s, v, o = np.nan, np.nan, np.nan
    else:
        if len(vp) > 1:
            vp = vp[0]  # use first 'VP' if all doesn't have prefix 'N'
            # Tree('VP', [...]) shape
            if len(vp) != 1:
                vp_ = ' '.join([x[0] for x in vp])
            else:
                vp_ = vp[0][0]
        else:
            # [Tree('VP', [...])] shape
            if len(vp[0]) != 1:
                vp_ = ' '.join([x[0] for x in vp[0]])
            else:
                vp_ = vp[0][0][0]
        # e.g. +76 can be captured as 'verb' -> then because of special characters in `regex`, we need to use r'
        # But we can think that this type of verb is somewhat error, so pass!
        try:
            m = re.search(vp_, text)
            start = m.start()
            end = m.end()
            s = text[:start].strip()
            v = vp_.strip()
            o = text[end:].strip()
        except:
            s, v, o = np.nan, np.nan, np.nan
                
    return s, v, o

# %%
df['clean_title'].apply(ExtractSVO_usingVPchunker)
# Out:
# 0     (Oakland Raiders fan, falls, from bleachers af...
# 1             (Blues' Cole, suspended, for three games)
# 2     (Kostitsyn's hat-trick, helps, Predators douse...
# 3     (Broncos, clinch, AFC West, snap playoff drought)
# 4       (Pope, Benedict, XVI to visit Cuba March 26-28)
# 5     (China, dissident-lawyer, Gao jailed in far west)
# 6     (Govt, appoints, 3-month interim head for Indi...
# 7     (Ravens, earn, AFC North title and first-round...
# 8     (Colombian police, kill, leader of powerful dr...
# 9                                       (nan, nan, nan)
# 10    (India, lets, foreign individuals invest in st...
# 11    (Freeport Indonesia union, says, delays return...
# 12    (Freeport Indonesia union, says, delays return...
# 13    (Philippine stock exchange, extends, trading h...
# 14           (Seoul shares, inch, up, tech shares lead)
# 15    (Hyundai Heavy, targets, 20 percent order grow...
# 16        (Proud 49ers secure bye with, win, over Rams)
# 17    (Hyundai Heavy, targets, 20 pct order growth i...
# 18                  (Market factors, to watch, - Jan 2)
# 19    (NASA, probes, reach moon for gravity-mapping ...
# 20                      (Fiji, to lift, emergency laws)
# 21                                      (nan, nan, nan)
# 22    (Ohio, suspends, well operations after series ...
# 23    (Brady, joins, "5,000 club" as Patriots get to...
# 24    (With 48 hours, left, , Romney eyes Iowa break...
# 25    (Romney, runs, strong, but can he connect with...
# 26    (Surging Rick Santorum, urges Iowa, to send "s...
# 27      (Bachmann, seeks miracle, in presidential race)
# 28      (Syria, bloodshed defies, Arab monitor mission)
# 29    (Hyundai, Kia eye 6 percent sales, rise, in 2012)
#                             ...
# 70     (Maersk, says, CEO on leave after heart surgery)
# 71    (Crisis talk, austerity, calls, mark euro anni...
# 72    (Educate young for peace, pope, says, at New Y...
# 73    (Supersized saddles, find, home on the range a...
# 74    (Gunmen attack, bars, in northeast Kenya, 5 dead)
# 75    (Israel cabinet, approves, ICL's Dead Sea salt...
# 76    (Israel, cabinet, OKs ICL's Dead Sea salt extr...
# 77        (Troops, tanks, patrol, in northeast Nigeria)
# 78    (Israel's Bank Leumi, CEO, Maor steps down aft...
# 79    (Porsche, wants, car sales to grow faster than...
# 80    (Verdasco, spoils, Hewitt's comeback in Hopman...
# 81    (Libya militia, says, holds Gaddafi supporters...
# 82    (Two die, 561, hurt, in Italian New Year celeb...
# 83         (Shell, CEO, keeping close eye on Petroplus)
# 84    (Shell, CEO, keeping close eye on Petroplus-pa...
# 85    (North Korea, calls, for "human shields" to pr...
# 86                                      (nan, nan, nan)
# 87                                      (nan, nan, nan)
# 88     (West in political crisis, has echoes, of 1930s)
# 89    (Mali gold revenues, rise, in 2011 alongside p...
# 90    (Nine, die, , 50 hurt in botched Congo jail br...
# 91    (Standard Chartered, sees, higher risk of euro...
# 92    (Iran successfully, tests domestically made, n...
# 93    (Romney, runs, strong, but can he connect with...
# 94                                      (nan, nan, nan)
# 95    (EU, sees, January decision on wider Iran sanc...
# 96    (UK, sells, Northern Rock to Virgin despite pr...
# 97                                      (nan, nan, nan)
# 98    (UK, sells, Northern Rock to Virgin despite pr...
# 99    (Holocaust, garb, causes outrage in Israel fai...
# Name: clean_title, Length: 100, dtype: object

# %% [markdown]
# ## All data: Extraction based on 'NP' & 'VP' Chunker

# %%
def ExtractSVO_usingNPVPchunker(text):
    """ For simplicity, we assume that if there are more than 2 'VP':
        -> We select First 'VP' 
    
    Error Type:
        text='Jinke Property wins land auctions in Chongqing for 117.9 mln yuan'
        > nltk.pos_tag recognize 'wins' as plural noun (NNS)
    """
    vp = []
    tree = NPVPchunker.parse(pos_tag(word_tokenize(text)))
    for child in tree:
        if str(type(child)) == "<class 'nltk.tree.Tree'>":
            if re.findall(r'\bVP\b', str(child)) != []:
                vp.append(child)
    if vp == []:
        s, v, o = np.nan, np.nan, np.nan
    else:
        if len(vp) > 1:
            vp = vp[0]  # use first 'VP' if all doesn't have prefix 'N'
            # Tree('VP', [...]) shape
            if len(vp) != 1:
                vp_ = ' '.join([x[0] for x in vp])
            else:
                vp_ = vp[0][0]
        else:
            # [Tree('VP', [...])] shape
            if len(vp[0]) != 1:
                vp_ = ' '.join([x[0] for x in vp[0]])
            else:
                vp_ = vp[0][0][0]
        # e.g. +76 can be captured as 'verb' -> then because of special characters in `regex`, we need to use r'
        # But we can think that this type of verb is somewhat error, so pass!
        try:
            m = re.search(vp_, text)
            start = m.start()
            end = m.end()
            s = text[:start].strip()
            v = vp_.strip()
            o = text[end:].strip()
        except:
            s, v, o = np.nan, np.nan, np.nan
                
    return s, v, o

# %%
dat_path = '/home/junhyuki/DLproject/DAT'
usecols=['connected_url', 'keywords', 'timestamp', 'clean_title', 'location']

def deleteNaN(df):
    """eliminate 'nan'"""
    idx_s = df[df['subject'].isna() == True].index
    idx_v = df[df['verb'].isna() == True].index
    idx_o = df[df['object'].isna() == True].index
    idx = list(set(list(set(idx_s)) + list(set(idx_v)) + list(set(idx_o))))
    df_new = df.drop(idx)
    print('original dataframe rows: ' + str(df.shape[0]) +
          ' -> after delete: ' + str(df_new.shape[0]))
    return df_new.reset_index(drop=True)

for year in np.arange(2012, 2019):
    print("processing {} news data...".format(year))
    df = pd.read_csv(dat_path + '/1-DailyNews/cleaned_news_{}.csv'.format(year), usecols=usecols)
    svo = df['clean_title'].apply(ExtractSVO_usingVPchunker)
    append = pd.DataFrame(list(svo), columns=['subject', 'verb', 'object'])
    df = df.join(append)
    df = deleteNaN(df)
    print(df.head())
    print(df.shape)
    df.to_csv(dat_path + '/2-SVO/NPVPchunker/SVO_chunker_{}.csv'.format(year), encoding='utf-8-sig', index=False)
# Out:
# processing 2012 news data...
# original dataframe rows: 277843 -> after delete: 234381
#                                        connected_url  \
# 0  http://www.reuters.com/article/2012/01/02/us-f...
# 1  http://www.reuters.com/article/2012/01/02/us-n...
# 2  http://www.reuters.com/article/2012/01/02/us-n...
# 3  http://www.reuters.com/article/2012/01/02/us-n...
# 4  http://www.reuters.com/article/2012/01/02/us-c...
#
#                                             keywords  timestamp  \
# 0  Juan Salceto;Stephen Glatstein;US;FOOTBALL;ACC...   20120101
# 1  Ian Cole;Justin Abdelkader;US;NHL;BLUES;COLE;N...   20120101
# 2  Barry Trotz;Brendan Morrison;Jarome Iginla;Kev...   20120101
# 3  Mark Leffingwell;Tim Tebow;US;NFL;BRONCOS;Spor...   20120101
# 4  Cuba;Mexico;Benedict XVI;Fidel Castro;Raul Cas...   20120101
#
#                                          clean_title location  \
# 0  Oakland Raiders fan falls from bleachers after...      NaN
# 1              Blues' Cole suspended for three games      NaN
# 2  Kostitsyn's hat-trick helps Predators douse Fl...      NaN
# 3      Broncos clinch AFC West, snap playoff drought      NaN
# 4        Pope Benedict XVI to visit Cuba March 26-28      NaN
#
#                  subject       verb                          object
# 0    Oakland Raiders fan      falls       from bleachers after game
# 1            Blues' Cole  suspended                 for three games
# 2  Kostitsyn's hat-trick      helps          Predators douse Flames
# 3                Broncos     clinch  AFC West, snap playoff drought
# 4                   Pope   Benedict   XVI to visit Cuba March 26-28
# (234381, 8)
# processing 2013 news data...
# original dataframe rows: 240771 -> after delete: 208391
#                                        connected_url  \
# 0  http://www.reuters.com/article/2013/01/02/us-u...
# 1  http://www.reuters.com/article/2013/01/02/us-u...
# 2  http://www.reuters.com/article/2013/01/02/us-u...
# 3  http://www.reuters.com/article/2013/01/02/usa-...
# 4  http://www.reuters.com/article/2013/01/02/indo...
#
#                                             keywords  timestamp  \
# 0  George W. Bush;US;USA;FISCAL;DEAL;Defense;Nati...   20130101
# 1  Barack Obama;US;USA;FISCAL;OBAMA;Lawmaking;Def...   20130101
# 2  Barack Obama;US;USA;FISCAL;OBAMA;HAWAII;Lawmak...   20130101
# 3  Barack Obama;USA;FISCAL/OBAMA;HAWAII (URGENT);...   20130101
# 4  Indonesia;INDONESIA;ECONOMY/TOURIST;Company Ne...   20130101
#
#                                          clean_title location  \
# 0  Key points in bill passed by Congress to avert...      NaN
# 1  After fiscal win, Obama warns Congress on debt...      NaN
# 2  Obama resumes Hawaii vacation after "fiscal cl...      NaN
# 3  Obama resumes Hawaii vacation after 'fiscal cl...      NaN
# 4  Indonesia Nov foreign tourist arrivals rise 5....      NaN
#
#                          subject      verb  \
# 0             Key points in bill    passed
# 1        After fiscal win, Obama     warns
# 2                          Obama   resumes
# 3                          Obama   resumes
# 4  Indonesia Nov foreign tourist  arrivals
#
#                                              object
# 0               by Congress to avert "fiscal cliff"
# 1                            Congress on debt fight
# 2  Hawaii vacation after "fiscal cliff" bill passes
# 3  Hawaii vacation after 'fiscal cliff' bill passes
# 4                                 rise 5.94 pct y/y
# (208391, 8)
# processing 2014 news data...
# original dataframe rows: 197732 -> after delete: 172938
#                                        connected_url  \
# 0  http://www.reuters.com/article/2014/01/02/maca...
# 1  http://www.reuters.com/article/2014/01/02/walm...
# 2  http://www.reuters.com/article/2014/01/02/indo...
# 3  http://www.reuters.com/article/2014/01/02/gfse...
# 4  http://www.reuters.com/article/2014/01/02/us-c...
#
#                                             keywords  timestamp  \
# 0  China;Macau;MACAU;REVENUES/ (URGENT);Hong Kong...   20140101
# 1  China;United States;Greg Foran;Shaun Rein;WALM...   20140101
# 2  Indonesia;INDONESIA;ECONOMY/TOURIST (URGENT);P...   20140101
# 3  GFSECURITIES/BRIEF (URGENT);Investment Banking...   20140101
# 4  China;GAO HUCHENG;Hongbin Qu;Yao Wei;US;CHINA;...   20140101
#
#                                          clean_title location  \
# 0  Macau gambling revenue rises 18.6 percent to $...      NaN
# 1  Wal-Mart recalls donkey product in China after...      NaN
# 2  Indonesia's foreign tourist arrivals hit recor...      NaN
# 3  GF Securities to issue the 1st tranche of shor...      NaN
# 4  China factory activity surveys confirm slowing...      NaN
#
#                        subject      verb  \
# 0       Macau gambling revenue     rises
# 1                     Wal-Mart   recalls
# 2  Indonesia's foreign tourist  arrivals
# 3                GF Securities  to issue
# 4       China factory activity   surveys
#
#                                               object
# 0                18.6 percent to $45 billion in 2013
# 1     donkey product in China after fox meat scandal
# 2                   hit record, up 16 pct y/y in Nov
# 3  the 1st tranche of short-term commercial paper...
# 4                           confirm slowing momentum
# (172938, 8)
# processing 2015 news data...
# original dataframe rows: 794284 -> after delete: 592160
#                                        connected_url  \
# 0  http://www.reuters.com/article/2015/01/01/us-u...
# 1  http://www.reuters.com/article/2015/01/01/indi...
# 2  http://www.reuters.com/article/2015/01/01/us-u...
# 3  http://www.reuters.com/article/2015/01/01/idUS...
# 4  http://www.reuters.com/article/2015/01/01/chin...
#
#                                             keywords  timestamp  \
# 0  Bobby Jindal;David Duke;Gilda Reed;John Boehne...   20150101
# 1  INDIA;CENBANK/REFINANCE (TABLE;URGENT);Banking...   20150101
# 2  United States;Anthony Grandison;Cleo Davis;Hea...   20150101
# 3                                                NaN   20150101
# 4  China;United States;CHINA;FREIGHT/;Commodities...   20150101
#
#                                          clean_title location  \
# 0  Democrat tipped blogger about Republican lawma...      NaN
# 1  Indian banks' refinancing with RBI rises to 98...      NaN
# 2  Maryland governor commutes sentences for remai...      NaN
# 3  The 218-Second 2015 TAIPEI 101 New Year Firewo...      NaN
# 4  China approves three new foreign courier firms...      NaN
#
#                                    subject            verb  \
# 0                                 Democrat  tipped blogger
# 1       Indian banks' refinancing with RBI  rises to 98.17
# 2               Maryland governor commutes       sentences
# 3  The 218-Second 2015 TAIPEI 101 New Year        Firework
# 4                                    China        approves
#
#                                               object
# 0  about Republican lawmaker meeting with white n...
# 1                                         bln rupees
# 2                    for remaining death row inmates
# 3    Show Featured "iSee Taiwan" and Light up Taipei
# 4            three new foreign courier firms -Xinhua
# (592160, 8)
# processing 2016 news data...
# original dataframe rows: 360290 -> after delete: 313391
#                                        connected_url  \
# 0  http://www.reuters.com/article/us-puertorico-z...
# 1  http://www.reuters.com/article/us-security-ger...
# 2  http://www.reuters.com/article/us-ghana-power-...
# 3  http://www.reuters.com/article/us-china-econom...
# 4  http://www.reuters.com/article/china-economy-p...
#
#                                             keywords  timestamp  \
# 0  Brazil;Colombia;Dominican Republic;El Salvador...   20160101
# 1  Hubertus Andrae;Joachim Herrmann;US;SECURITY;G...   20160101
# 2  Ghana;Dzifa Attivor;John Mahama;US;GHANA;POWER...   20160101
# 3  China;Singapore;Zhou Hao;US;CHINA;ECONOMY;PMI;...   20160101
# 4  China;Singapore;Zhou Hao;CHINA;ECONOMY/PMI;OFF...   20160101
#
#                                          clean_title location  \
# 0  Puerto Rico reports first case of Zika virus, ...      NaN
# 1  Germany says it has information Islamic State ...      NaN
# 2  Ghana minister resigns for 'unsatisfactory han...      NaN
# 3  China December factory activity shrinks, more ...      NaN
# 4  China Dec factory activity shrinks, more stimu...  BEIJING
#
#                                              subject     verb  \
# 0      Puerto Rico reports first case of Zika virus,   spread
# 1                                            Germany     says
# 2                                     Ghana minister  resigns
# 3  China December factory activity shrinks, more ...   needed
# 4  China Dec factory activity shrinks, more stimulus   needed
#
#                                               object
# 0                                      by mosquitoes
# 1  it has information Islamic State planned suici...
# 2  for 'unsatisfactory handling' of electricity c...
# 3                                            in 2016
# 4                                            in 2016
# (313391, 8)
# processing 2017 news data...
# original dataframe rows: 216089 -> after delete: 189041
#                                        connected_url  \
# 0  http://www.reuters.com/article/us-people-bened...
# 1  http://www.reuters.com/article/people-benedict...
# 2  http://www.reuters.com/article/us-china-econom...
# 3  http://www.reuters.com/article/us-health-birdf...
# 4  http://www.reuters.com/article/health-birdflu-...
#
#                                             keywords  timestamp  \
# 0  United Kingdom;United States;Ancestry;Arthur C...   20170101
# 1  United Kingdom;United States;Ancestry;Arthur C...   20170101
# 2  China;Zhou Hao;US;CHINA;ECONOMY;PMI;Asia / Pac...   20170101
# 3  China;US;HEALTH;BIRDFLU;CHINA;Health / Medicin...   20170101
# 4  China;US;HEALTH;BIRDFLU;CHINA;Health / Medicin...   20170101
#
#                                          clean_title location  \
# 0  Benedict Cumberbatch and Sherlock Holmes is ma...      NaN
# 1  Benedict Cumberbatch and Sherlock Holmes is ma...      NaN
# 2  Growth in China's factories, services slows in...      NaN
# 3         China confirms another human bird flu case      NaN
# 4         China confirms another human bird flu case      NaN
#
#                                     subject           verb  \
# 0  Benedict Cumberbatch and Sherlock Holmes  is match made
# 1  Benedict Cumberbatch and Sherlock Holmes  is match made
# 2     Growth in China's factories, services          slows
# 3                                     China       confirms
# 4                                     China       confirms
#
#                         object
# 0                   in history
# 1                   in history
# 2                  in December
# 3  another human bird flu case
# 4  another human bird flu case
# (189041, 8)
# processing 2018 news data...
# original dataframe rows: 156384 -> after delete: 137221
#                                        connected_url  \
# 0  http://www.reuters.com/article/china-film/chin...
# 1  http://www.reuters.com/article/us-italy-electi...
# 2  http://www.reuters.com/article/brief-tibet-gal...
# 3  http://www.reuters.com/article/brief-dalian-ze...
# 4  http://www.reuters.com/article/us-football-nfl...
#
#                                             keywords  timestamp  \
# 0  US;CHINA;FILM;Asia / Pacific;Film;Living / Lif...   20180101
# 1  US;ITALY;ELECTION;Elections / Voting;Governmen...   20180101
# 2  BRIEF;Tibet Galaxy Science and Technology Deve...   20180101
# 3  BRIEF;Dalian Zeus Entertainment unit sells 30....   20180101
# 4  US;FOOTBALL;NFL;COACHES;Sport;NFL American Foo...   20180101
#
#                                          clean_title location  \
# 0  China box office posts turnaround in 2017 with...      NaN
# 1  Italian president calls for 'realistic' propos...      NaN
# 2  Tibet Galaxy Science and Technology Developmen...      NaN
# 3  Dalian Zeus Entertainment unit sells 30.3 pct ...      NaN
# 4  Two head coaches gone as Raiders fire Del Rio,...      NaN
#
#                                            subject         verb  \
# 0                           China box office posts   turnaround
# 1                                Italian president        calls
# 2  Tibet Galaxy Science and Technology Development  to dissolve
# 3                   Dalian Zeus Entertainment unit        sells
# 4                                         Two head      coaches
#
#                                             object
# 0                       in 2017 with 13 pct growth
# 1      for 'realistic' proposals ahead of election
# 2                                      three units
# 3                 30.3 pct stake in info-tech unit
# 4  gone as Raiders fire Del Rio, Colts dump Pagano
# (137221, 8)

# %% [markdown]
# ## Evaluation

# %%
df = pd.read_csv(dat_path + '/2-SVO/NPVPchunker/SVO_chunker_{}.csv'.format(2012))

# %%
import numpy as np
idx = np.random.choice(len(df), 20)
df[['clean_title', 'subject', 'verb', 'object']].iloc[idx]
# Out:
#                                               clean_title  \
# 143821    Euro extends losses vs dollar, hits session low
# 205267  IIF warns of risk from delaying Greek aid paym...
# 161964  U.S. swaps regulator says should rely on some ...
# 153712             Brent crude futures extend gains to $1
# 105252         KKR raises $3 billion for second Asia fund
# 8112     Putin aide says Kremlin must face up to protests
# 110887  Kidnapped Saudi envoy urges king not to forget...
# 129715  Israel denies report Obama aide shared Iran wa...
# 129516  CBS says no fear of TV shows getting drowned o...
# 35652   U.S. wants "early" return of U.N. inspectors t...
# 111243         CEZ receives bids for nuke plant expansion
# 207944  Manulife says Asia growth to lead less volatil...
# 11336           Ireland moves to avoid 2014 funding cliff
# 120315  German ZEW index drops for third straight mont...
# 78378     Investors losing faith in commodity hedge funds
# 45474   Bank of America tests new home foreclosure pro...
# 209758        upcoming film will be last big action movie
# 61998        Nordex to pull out of offshore wind business
# 151455   Trayvon Martin shooter wins appeal for new judge
# 224774  China sentences three to die for attempted Xin...
#
#                        subject           verb  \
# 143821                    Euro        extends
# 205267                     IIF          warns
# 161964    U.S. swaps regulator           says
# 153712     Brent crude futures         extend
# 105252                     KKR         raises
# 8112                Putin aide           says
# 110887         Kidnapped Saudi          envoy
# 129715                  Israel  denies report
# 129516                     CBS           says
# 35652                     U.S.          wants
# 111243                     CEZ       receives
# 207944                Manulife           says
# 11336                  Ireland          moves
# 120315        German ZEW index          drops
# 78378                Investors         losing
# 45474          Bank of America          tests
# 209758           upcoming film        will be
# 61998                   Nordex        to pull
# 151455  Trayvon Martin shooter           wins
# 224774   China sentences three         to die
#
#                                                    object
# 143821                 losses vs dollar, hits session low
# 205267           of risk from delaying Greek aid payments
# 161964                  should rely on some foreign rules
# 153712                                        gains to $1
# 105252                    $3 billion for second Asia fund
# 8112                     Kremlin must face up to protests
# 110887                       urges king not to forget him
# 129715                    Obama aide shared Iran war plan
# 129516  no fear of TV shows getting drowned out by mon...
# 35652    "early" return of U.N. inspectors to North Korea
# 111243                      bids for nuke plant expansion
# 207944         Asia growth to lead less volatile earnings
# 11336                         to avoid 2014 funding cliff
# 120315                   for third straight month in July
# 78378                      faith in commodity hedge funds
# 45474                        new home foreclosure program
# 209758                              last big action movie
# 61998                       out of offshore wind business
# 151455                               appeal for new judge
# 224774                   for attempted Xinjiang hijacking

# %% [markdown]
# ## Appendix:
#
# Souce: **Tree Syntax of Natural Language (Lecture Note)**
#
# ```
# """
#
#
# TABLE 1.______________________________________
# <label> <longname>              <example>
# NN      singular                noun pyramid
# NNS     plural noun             lectures
# NNP     proper noun             Khufu
# VBD     past tense verb         claimed
# VBZ     3rd person singular     is
#         present tense verb
# VBP     non-3rd person singular have
#         present tense verb
# VBN     past participle         found
# PRP     pronoun                 they
# PRP$    possessive pronoun      their
# JJ      adjective               public
# IN      preposition             in
#         complementizer          that
# DT      determiner              the
#
# TABLE 2._________________________________________________
# <label> <longname>              <example>(represented by terminal string)
# NP      noun phrase             their public lectures
# VP      verb phrase             built the pyramid
# PP      prepositional           in the five chambers
#         phrase
# S       sentence                Khufu built the pyramid
# SBAR    sbar                    that Khufu built the pyramid
#
#
# Part of speech tags for verbs____________________________________
# TABLE 3._________________________________________________________
# <Tag>   <Long name>         <Example>
# VBD     past tense          He ate/VBD the cookies.
#                             She answered/VBD the question.
#
# VBZ     present tense       He likes/VBZ cookies.
#
# VBP     present tense       They like/VBP cookies.
#         3rd person          They answer/VBP such questions.
#         plural              They are/VBP tired.
#
# VB      base                He may like/VB cookies.
#                             I heard her answer/VB the question.
#                             They may be/VB tired.
#
# VBG     present participle, Eating/VG cookies is unhealthy.
#         Gform               He likes eating/VG cookies.
#
# VBN     past participle,    He has eaten/VBN the cookies.
#         N-form              She has ansered/VBN the questions.
#                             My question was not answered/VBN.
#
# MD      modal               She will/MD prevail.
# TO      auxiliary to        She expects to/TO prevail.
#
# """
# ```
#
# Some other References:
#     **Introduction to the CoNLL-2000 Shared Task: Chunking (2000, Tjong et al.)**
